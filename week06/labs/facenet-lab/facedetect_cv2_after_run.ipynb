# %%
import numpy as np
import cv2

# %%
# from PIL import Image
from matplotlib import pyplot as plt
import matplotlib.patches as patches

# %%
face_cascade = cv2.CascadeClassifier('/usr/share/opencv4/haarcascades/haarcascade_frontalface_default.xml')

# %%
# go warriors!
IMAGE_PATH = 'warriors.jpg'
# !wget 'https://cdn.vox-cdn.com/thumbor/rC0mlBATZdoDW1tEa44P6431sGc=/0x0:3683x2455/1200x800/filters:focal(1623x234:2211x822)/cdn.vox-cdn.com/uploads/chorus_image/image/63273148/usa_today_12005182.0.jpg' -O {IMAGE_PATH}
# Out:
# --2021-02-18 23:49:16--  https://cdn.vox-cdn.com/thumbor/rC0mlBATZdoDW1tEa44P6431sGc=/0x0:3683x2455/1200x800/filters:focal(1623x234:2211x822)/cdn.vox-cdn.com/uploads/chorus_image/image/63273148/usa_today_12005182.0.jpg
# Resolving cdn.vox-cdn.com (cdn.vox-cdn.com)... 199.232.192.124, 199.232.196.124
# Connecting to cdn.vox-cdn.com (cdn.vox-cdn.com)|199.232.192.124|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116962 (114K) [image/jpeg]
# Saving to: 'warriors.jpg'
#
# warriors.jpg        100%[===================>] 114.22K  --.-KB/s    in 0.1s
#
# 2021-02-18 23:49:16 (844 KB/s) - 'warriors.jpg' saved [116962/116962]

# %%
image = cv2.imread(IMAGE_PATH)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
plt.figure(figsize=(12, 8))
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 1199.5, 799.5, -0.5)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
fig, ax = plt.subplots(figsize=(16, 12))
ax.imshow(image)
# ax.axis('off')

for x,y,w,h in faces:
        # display rectangle
    patch = patches.Rectangle((x, y), w, h, color='g', alpha=0.3)
    ax.add_patch(patch)
fig.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
# %%time
for i in range(1,100):
    # Detect faces
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
# Out:
# CPU times: user 1min 1s, sys: 400 ms, total: 1min 1s
# Wall time: 32.6 s

# %%
faces[0]
# Out:
# array([991, 405,  53,  53], dtype=int32)
